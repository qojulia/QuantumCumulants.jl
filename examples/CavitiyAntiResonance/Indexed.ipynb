# %%
#Cavity Antiresonance example using Index
#This file is for testing

# %%
using QuantumOptics
using OrdinaryDiffEq
using ModelingToolkit
using LinearAlgebra
using Symbolics
using SymbolicUtils
using DifferentialEquations
using Plots

# %%
include("../../src/indexing.jl")
include("../../src/doubleSums.jl")
include("../../src/averageSums.jl")
include("../../src/indexedMeanfield.jl")
# Out:
# substReds (generic function with 2 methods)

# %%
order = 2
@cnumbers Δc η Δa κ

N = 2 #number of atoms
hc = FockSpace(:cavity)
ha = NLevelSpace(Symbol(:atom),2)
h = hc ⊗ ha

#define indices
i_ind = Index(h,:i,N,ha)
j_ind = Index(h,:j,N,ha)
k_ind = Index(h,:k,N,ha)

#define indexed variables
g(k) = IndexedVariable(:g,k)
Γ_ij = DoubleIndexedVariable(:Γ,i_ind,j_ind,true)
Ω_ij = DoubleIndexedVariable(:Ω,i_ind,j_ind,false)

@qnumbers a::Destroy(h)
σ(i,j,k) = IndexedOperator(Transition(h,:σ,i,j),k)
# Out:
# σ (generic function with 1 method)

# %%
# Hamiltonian
Hc = Δc*a'a + η*(a' + a)
#Ha = Δa*sum(σ(2,2,k) for k=1:N) + sum(Ω(i,j)*σ(2,1,i)*σ(1,2,j)*(i≠j) for i=1:N for j=1:N)
Ha = Δa*IndexedSingleSum(σ(2,2,i_ind),i_ind) + IndexedDoubleSum(Ω_ij*σ(2,1,i_ind)*σ(1,2,j_ind),j_ind,i_ind,true)
#Hi = sum(g(k)*(a'σ(1,2,k) + a*σ(2,1,k)) for k=1:N)
Hi = IndexedSingleSum(g(i_ind)*(a'*σ(1,2,i_ind) + a*σ(2,1,i_ind)),i_ind)
H = Hc + Ha + Hi
# Out:
# (η*(a′)+η*(a)+Δc*(a′*a)+Σ(i=1:2)Δa*(σ22i)+Σ(j=1:2)Σ(i=1:2)(i≠j)Ωij*(σ21i*σ12j)+Σ(i=1:2)gi*(a′*σ12i)+Σ(i=1:2)gi*(a*σ21i))

# %%
# Jump operators & and rates
#J = [a, [σ(1,2,k) for k=1:N]]
J = [a, [σ(1,2,i_ind),σ(1,2,j_ind)] ] 
#rates = [κ, [Γ(i,j) for i=1:N, j=1:N]]
#rates = [κ,Γ_ij]
rates = [κ,Γ_ij]
# Out:
# 2-element Vector{Sym{Parameter}}:
#  κ
#  Γij

# %%
ops = [a, σ(2,2,k_ind), σ(1,2,k_ind)]
eqs = indexedMeanfield(ops,H,J;rates=rates,order=order)
# Out:
# ∂ₜ(⟨a⟩) = (0 - 1im)*η + (0 - 1im)*var"∑(i=1:2)gi*⟨σ12i⟩" + (0 - 1im)*Δc*⟨a⟩ - 0.5κ*⟨a⟩
# ∂ₜ(⟨σ22k⟩) = (0 + 1im)*var"∑(i=1:2)(i≠j,k)Ωik*⟨σ21i*σ12k⟩" + (0 - 1im)*var"∑(j=1:2)(j≠k)Ωkj*⟨σ12j*σ21k⟩" + (0 + 1im)*gk*⟨a′*σ12k⟩ + (0 - 1im)*gk*⟨a*σ21k⟩ - 0.5var"∑(i=1:2)(i≠j,k)Γik*⟨σ21i*σ12k⟩" - 0.5var"∑(j=1:2)(j≠k)Γkj*⟨σ12j*σ21k⟩" - Γkk*⟨σ22k⟩
# ∂ₜ(⟨σ12k⟩) = var"∑(j=1:2)(j≠k)Γkj*⟨σ12j*σ22k⟩" + (0 - 1im)*var"∑(j=1:2)(j≠k)Ωkj*⟨σ12j⟩" + (0 + 2im)*var"∑(j=1:2)(j≠k)Ωkj*⟨σ12j*σ22k⟩" + (0 - 1im)*gk*⟨a⟩ + (0 - 1im)*Δa*⟨σ12k⟩ + (0 + 2im)*gk*⟨a*σ22k⟩ - 0.5var"∑(j=1:2)Γkj*⟨σ12j⟩"

# %%
eqs_comp = indexedComplete(eqs;extraIndices=[:q])
1
# Out:
# 1

# %%
eqs_comp
# Out:
# ∂ₜ(⟨a⟩) = (0 - 1im)*η + (0 - 1im)*var"∑(i=1:2)gi*⟨σ12i⟩" + (0 - 1im)*Δc*⟨a⟩ - 0.5κ*⟨a⟩
# ∂ₜ(⟨σ22k⟩) = (0 + 1im)*var"∑(i=1:2)(i≠j,k)Ωik*⟨σ21i*σ12k⟩" + (0 - 1im)*var"∑(j=1:2)(j≠k)Ωkj*⟨σ12j*σ21k⟩" + (0 + 1im)*gk*⟨a′*σ12k⟩ + (0 - 1im)*gk*⟨a*σ21k⟩ - 0.5var"∑(i=1:2)(i≠j,k)Γik*⟨σ21i*σ12k⟩" - 0.5var"∑(j=1:2)(j≠k)Γkj*⟨σ12j*σ21k⟩" - Γkk*⟨σ22k⟩
# ∂ₜ(⟨σ12k⟩) = var"∑(j=1:2)(j≠k)Γkj*⟨σ12j*σ22k⟩" + (0 - 1im)*var"∑(j=1:2)(j≠k)Ωkj*⟨σ12j⟩" + (0 + 2im)*var"∑(j=1:2)(j≠k)Ωkj*⟨σ12j*σ22k⟩" + (0 - 1im)*gk*⟨a⟩ + (0 - 1im)*Δa*⟨σ12k⟩ + (0 + 2im)*gk*⟨a*σ22k⟩ - 0.5var"∑(j=1:2)Γkj*⟨σ12j⟩"
# ∂ₜ(⟨a′*σ12k⟩) = var"∑(j=1:2)(j≠k)Γkj*⟨a′⟩*⟨σ12j*σ22k⟩" + var"∑(j=1:2)(j≠k)Γkj*⟨σ12j⟩*⟨a′*σ22k⟩" + var"∑(j=1:2)(j≠k)Γkj*⟨σ22k⟩*⟨a′*σ12j⟩" + (0 + 1im)*var"∑(i=1:2)(i≠k)gi*⟨σ21i*σ12k⟩" + (0 - 1im)*var"∑(j=1:2)(j≠k)Ωkj*⟨a′*σ12j⟩" + (0 + 2im)*var"∑(j=1:2)(j≠k)Ωkj*⟨a′⟩*⟨σ12j*σ22k⟩" + (0 - 4im)*var"∑(j=1:2)(j≠k)Ωkj*⟨a′⟩*⟨σ12j⟩*⟨σ22k⟩" + (0 + 2im)*var"∑(j=1:2)(j≠k)Ωkj*⟨σ12j⟩*⟨a′*σ22k⟩" + (0 + 2im)*var"∑(j=1:2)(j≠k)Ωkj*⟨σ22k⟩*⟨a′*σ12j⟩" + (0 + 1im)*gk*⟨σ22k⟩ + (0 - 1im)*gk*⟨a′*a⟩ + (0 + 1im)*η*⟨σ12k⟩ + (0 - 1im)*Δa*⟨a′*σ12k⟩ + (0 + 1im)*Δc*⟨a′*σ12k⟩ + (0 + 2im)*gk*(⟨a′⟩*⟨a*σ22k⟩ + ⟨σ22k⟩*⟨a′*a⟩ + ⟨a⟩*⟨a′*σ22k⟩ - 2⟨a′⟩*⟨a⟩*⟨σ22k⟩) - 0.5var"∑(j=1:2)Γkj*⟨a′*σ12j⟩" - 2var"∑(j=1:2)(j≠k)Γkj*⟨a′⟩*⟨σ12j⟩*⟨σ22k⟩" - 0.5κ*⟨a′*σ12k⟩
# ∂ₜ(⟨a*σ22k⟩) = var"∑(i=1:2)(i≠j,k)Γik*⟨a⟩*⟨σ21i⟩*⟨σ12k⟩" + var"∑(j=1:2)(j≠k)Γkj*⟨a⟩*⟨σ12j⟩*⟨σ21k⟩" + (0.0 + 1.0im)*var"∑(i=1:2)(i≠j,k)Ωik*⟨σ12k⟩*⟨a*σ21i⟩" + (0.0 + 1.0im)*var"∑(i=1:2)(i≠j,k)Ωik*⟨a⟩*⟨σ21i*σ12k⟩" + (0.0 + 1.0im)*var"∑(i=1:2)(i≠j,k)Ωik*⟨σ21i⟩*⟨a*σ12k⟩" + (0 - 1im)*var"∑(i=1:2)(i≠k)gi*⟨σ12i*σ22k⟩" + (0 - 1im)*var"∑(j=1:2)(j≠k)Ωkj*⟨a⟩*⟨σ12j*σ21k⟩" + (-0.5 + 0.0im)var"∑(i=1:2)(i≠j,k)Γik*⟨a⟩*⟨σ21i*σ12k⟩" + (-0.5 + 0.0im)var"∑(i=1:2)(i≠j,k)Γik*⟨σ12k⟩*⟨a*σ21i⟩" + (-0.5 + 0.0im)var"∑(i=1:2)(i≠j,k)Γik*⟨σ21i⟩*⟨a*σ12k⟩" + (0 - 1im)*var"∑(j=1:2)(j≠k)Ωkj*⟨σ12j⟩*⟨a*σ21k⟩" + (0 - 1im)*var"∑(j=1:2)(j≠k)Ωkj*⟨σ21k⟩*⟨a*σ12j⟩" + (0.0 - 2.0im)*var"∑(i=1:2)(i≠j,k)Ωik*⟨a⟩*⟨σ21i⟩*⟨σ12k⟩" + (0 + 2im)*var"∑(j=1:2)(j≠k)Ωkj*⟨a⟩*⟨σ12j⟩*⟨σ21k⟩" + (0 - 1im)*gk*(⟨σ21k⟩*⟨a*a⟩ + 2⟨a⟩*⟨a*σ21k⟩ - 2(⟨a⟩^2)*⟨σ21k⟩) + (0 + 1im)*gk*(⟨a′⟩*⟨a*σ12k⟩ + ⟨σ12k⟩*⟨a′*a⟩ + ⟨a⟩*⟨a′*σ12k⟩ - 2⟨a′⟩*⟨a⟩*⟨σ12k⟩) + (0 - 1im)*Δc*⟨a*σ22k⟩ + (0 - 1im)*η*⟨σ22k⟩ - 0.5var"∑(j=1:2)(j≠k)Γkj*⟨a⟩*⟨σ12j*σ21k⟩" - 0.5var"∑(j=1:2)(j≠k)Γkj*⟨σ12j⟩*⟨a*σ21k⟩" - 0.5var"∑(j=1:2)(j≠k)Γkj*⟨σ21k⟩*⟨a*σ12j⟩" - 0.5κ*⟨a*σ22k⟩ - Γkk*⟨a*σ22k⟩
# ∂ₜ(⟨σ12k*σ21q⟩) = var"∑(i=1:2)(i≠j,k,q)Γiq*⟨σ12k⟩*⟨σ21i*σ22q⟩" + var"∑(i=1:2)(i≠j,k,q)Γiq*⟨σ21i⟩*⟨σ12k*σ22q⟩" + var"∑(i=1:2)(i≠j,k,q)Γiq*⟨σ22q⟩*⟨σ21i*σ12k⟩" + var"∑(j=1:2)(j≠k,q)Γkj*⟨σ12j⟩*⟨σ22k*σ21q⟩" + var"∑(j=1:2)(j≠k,q)Γkj*⟨σ21q⟩*⟨σ12j*σ22k⟩" + var"∑(j=1:2)(j≠k,q)Γkj*⟨σ22k⟩*⟨σ12j*σ21q⟩" + (0.0 + 1.0im)*var"(k≠q)gq*⟨a′*σ12k⟩" + (0.0 + 2.0im)*var"(k≠q)gk*(⟨σ21q⟩*⟨a*σ22k⟩ + ⟨a⟩*⟨σ22k*σ21q⟩ + ⟨σ22k⟩*⟨a*σ21q⟩ - 2⟨a⟩*⟨σ21q⟩*⟨σ22k⟩)" + (0.0 - 2.0im)*var"(k≠q)gq*(⟨a′⟩*⟨σ12k*σ22q⟩ + ⟨σ22q⟩*⟨a′*σ12k⟩ + ⟨σ12k⟩*⟨a′*σ22q⟩ - 2⟨a′⟩*⟨σ22q⟩*⟨σ12k⟩)" + 1.5var"(k≠q)Γkq*⟨σ22k*σ22q⟩" + (0.0 - 1.0im)*var"(k≠q)gk*⟨a*σ21q⟩" + (0 - 2im)*var"∑(i=1:2)(i≠j,k,q)Ωiq*⟨σ12k⟩*⟨σ21i*σ22q⟩" + (0 - 2im)*var"∑(i=1:2)(i≠j,k,q)Ωiq*⟨σ21i⟩*⟨σ12k*σ22q⟩" + (0.0 + 1.0im)*var"(k≠q)Ωkq*⟨σ22k*σ22q⟩" + (0.0 - 1.0im)*var"(k≠q)Ωkq*⟨σ22q⟩" + (0 + 1im)*var"∑(i=1:2)(i≠j,k,q)Ωiq*⟨σ21i*σ12k⟩" + (0 - 2im)*var"∑(i=1:2)(i≠j,k,q)Ωiq*⟨σ22q⟩*⟨σ21i*σ12k⟩" + (0 + 2im)*var"∑(j=1:2)(j≠k,q)Ωkj*⟨σ12j⟩*⟨σ22k*σ21q⟩" + (0 + 4im)*var"∑(i=1:2)(i≠j,k,q)Ωiq*⟨σ22q⟩*⟨σ21i⟩*⟨σ12k⟩" + (0 - 1im)*var"∑(j=1:2)(j≠k,q)Ωkj*⟨σ12j*σ21q⟩" + (0 - 4im)*var"∑(j=1:2)(j≠k,q)Ωkj*⟨σ12j⟩*⟨σ21q⟩*⟨σ22k⟩" + (0 + 2im)*var"∑(j=1:2)(j≠k,q)Ωkj*⟨σ21q⟩*⟨σ12j*σ22k⟩" + (0 + 2im)*var"∑(j=1:2)(j≠k,q)Ωkj*⟨σ22k⟩*⟨σ12j*σ21q⟩" + 0.5Γkq*⟨σ22k*σ22q⟩ - 0.5var"(k≠q)Γkq*⟨σ22q⟩" - 0.5var"(k≠q)Γqq*⟨σ12k*σ21q⟩" - 0.5var"(k≠q)Γkk*⟨σ12k*σ21q⟩" - 0.5var"∑(i=1:2)(i≠j,k,q)Γiq*⟨σ21i*σ12k⟩" - 2var"∑(i=1:2)(i≠j,k,q)Γiq*⟨σ22q⟩*⟨σ21i⟩*⟨σ12k⟩" - 0.5var"∑(j=1:2)(j≠k,q)Γkj*⟨σ12j*σ21q⟩" - 2var"∑(j=1:2)(j≠k,q)Γkj*⟨σ12j⟩*⟨σ21q⟩*⟨σ22k⟩" - 0.5Γkq*⟨σ22k⟩
# ∂ₜ(⟨σ22k*σ12q⟩) = var"∑(j=1:2)(j≠k,q)Γkj*⟨σ12q⟩*⟨σ12j⟩*⟨σ21k⟩" + var"∑(j=1:2)(j≠k,q)Γqj*⟨σ12j⟩*⟨σ22k*σ22q⟩" + var"∑(j=1:2)(j≠k,q)Γqj*⟨σ22k⟩*⟨σ12j*σ22q⟩" + var"∑(j=1:2)(j≠k,q)Γqj*⟨σ22q⟩*⟨σ12j*σ22k⟩" + (0.0 + 1.0im)*var"(k≠q)gk*(⟨a′⟩*⟨σ12k*σ12q⟩ + ⟨σ12q⟩*⟨a′*σ12k⟩ + ⟨σ12k⟩*⟨a′*σ12q⟩ - 2⟨a′⟩*⟨σ12q⟩*⟨σ12k⟩)" + (0.0 - 1.0im)*var"(k≠q)gk*(⟨a⟩*⟨σ21k*σ12q⟩ + ⟨σ21k⟩*⟨a*σ12q⟩ + ⟨σ12q⟩*⟨a*σ21k⟩ - 2⟨a⟩*⟨σ12q⟩*⟨σ21k⟩)" + (0.0 + 2.0im)*var"(k≠q)gq*(⟨σ22k⟩*⟨a*σ22q⟩ + ⟨σ22q⟩*⟨a*σ22k⟩ + ⟨a⟩*⟨σ22k*σ22q⟩ - 2⟨a⟩*⟨σ22q⟩*⟨σ22k⟩)" + (0.0 - 1.0im)*var"(k≠q)Δa*⟨σ22k*σ12q⟩" + (0.0 + 1.0im)*var"(k≠q)Ωqk*⟨σ12k*σ22q⟩" + (0.0 - 1.0im)*var"(k≠q)gq*⟨a*σ22k⟩" + (0 - 1im)*var"∑(j=1:2)(j≠k,q)Ωkj*⟨σ12j⟩*⟨σ21k*σ12q⟩" + (0 - 1im)*var"∑(j=1:2)(j≠k,q)Ωkj*⟨σ12q⟩*⟨σ12j*σ21k⟩" + (0 + 2im)*var"∑(j=1:2)(j≠k,q)Ωkj*⟨σ12q⟩*⟨σ12j⟩*⟨σ21k⟩" + (0 - 1im)*var"∑(j=1:2)(j≠k,q)Ωkj*⟨σ21k⟩*⟨σ12j*σ12q⟩" + (0 + 1im)*var"∑(j=1:2)(j≠k,q)Ωqj*⟨σ12j⟩*⟨σ22k*σ22q⟩" + (0 + 1im)*var"∑(j=1:2)(j≠k,q)Ωqj*⟨σ22k⟩*⟨σ12j*σ22q⟩" + (0 + 1im)*var"∑(j=1:2)(j≠k,q)Ωqj*⟨σ22q⟩*⟨σ12j*σ22k⟩" + (0 - 1im)*var"∑(j=1:2)(j≠q,k)Ωqj*⟨σ12j*σ22k⟩" + (0 + 1im)*var"∑(j=1:2)(j≠q,k)Ωqj*⟨σ12j⟩*⟨σ22k*σ22q⟩" + (0 + 1im)*var"∑(j=1:2)(j≠q,k)Ωqj*⟨σ22k⟩*⟨σ12j*σ22q⟩" + (0 + 1im)*var"∑(j=1:2)(j≠q,k)Ωqj*⟨σ22q⟩*⟨σ12j*σ22k⟩" + (0 - 2im)*var"∑(j=1:2)(j≠k,q)Ωqj*⟨σ22q⟩*⟨σ12j⟩*⟨σ22k⟩" + (0 - 2im)*var"∑(j=1:2)(j≠q,k)Ωqj*⟨σ22q⟩*⟨σ12j⟩*⟨σ22k⟩" - 0.5var"(k≠q)Γqk*⟨σ12k*σ22q⟩" - 0.5var"∑(j=1:2)(j≠k)Γqj*⟨σ12j*σ22k⟩" - 0.5var"∑(j=1:2)(j≠k,q)Γkj*⟨σ12j⟩*⟨σ21k*σ12q⟩" - 2var"∑(j=1:2)(j≠k,q)Γqj*⟨σ22q⟩*⟨σ12j⟩*⟨σ22k⟩" - 0.5var"∑(j=1:2)(j≠k,q)Γkj*⟨σ12q⟩*⟨σ12j*σ21k⟩" - 0.5var"∑(j=1:2)(j≠k,q)Γkj*⟨σ21k⟩*⟨σ12j*σ12q⟩" - var"(k≠q)Γkk*⟨σ22k*σ12q⟩"
# ∂ₜ(⟨a′*a⟩) = (0 + 1im)*var"∑(i=1:2)gi*⟨a*σ21i⟩" + (0 - 1im)*var"∑(i=1:2)gi*⟨a′*σ12i⟩" + (0 - 1im)*η*⟨a′⟩ + (0 + 1im)*η*⟨a⟩ - κ*⟨a′*a⟩
# ∂ₜ(⟨a*a⟩) = (0 - 2im)*var"∑(i=1:2)gi*⟨a*σ12i⟩" + (0 - 2im)*η*⟨a⟩ + (0 - 2im)*Δc*⟨a*a⟩ - κ*⟨a*a⟩
# ∂ₜ(⟨a*σ12k⟩) = var"∑(j=1:2)(j≠k)Γkj*⟨a⟩*⟨σ12j*σ22k⟩" + var"∑(j=1:2)(j≠k)Γkj*⟨σ12j⟩*⟨a*σ22k⟩" + var"∑(j=1:2)(j≠k)Γkj*⟨σ22k⟩*⟨a*σ12j⟩" + (0 - 1im)*var"∑(i=1:2)(i≠k)gi*⟨σ12i*σ12k⟩" + (0 - 1im)*var"∑(j=1:2)(j≠k)Ωkj*⟨a*σ12j⟩" + (0 + 2im)*var"∑(j=1:2)(j≠k)Ωkj*⟨a⟩*⟨σ12j*σ22k⟩" + (0 - 4im)*var"∑(j=1:2)(j≠k)Ωkj*⟨a⟩*⟨σ12j⟩*⟨σ22k⟩" + (0 + 2im)*var"∑(j=1:2)(j≠k)Ωkj*⟨σ12j⟩*⟨a*σ22k⟩" + (0 + 2im)*var"∑(j=1:2)(j≠k)Ωkj*⟨σ22k⟩*⟨a*σ12j⟩" + (0 - 1im)*gk*⟨a*a⟩ + (0 - 1im)*Δa*⟨a*σ12k⟩ + (0 - 1im)*η*⟨σ12k⟩ + (0 - 1im)*Δc*⟨a*σ12k⟩ + (0 + 2im)*gk*(⟨σ22k⟩*⟨a*a⟩ + 2⟨a⟩*⟨a*σ22k⟩ - 2(⟨a⟩^2)*⟨σ22k⟩) - 2var"∑(j=1:2)(j≠k)Γkj*⟨a⟩*⟨σ12j⟩*⟨σ22k⟩" - 0.5var"∑(j=1:2)Γkj*⟨a*σ12j⟩" - 0.5κ*⟨a*σ12k⟩
# ∂ₜ(⟨σ22k*σ22q⟩) = var"∑(i=1:2)(i≠j,k,q)Γiq*⟨σ12q⟩*⟨σ21i⟩*⟨σ22k⟩" + var"∑(j=1:2)(j≠k,q)Γkj*⟨σ22q⟩*⟨σ12j⟩*⟨σ21k⟩" + var"∑(j=1:2)(j≠k,q)Γqj*⟨σ12j⟩*⟨σ21q⟩*⟨σ22k⟩" + (0.0 + 1.0im)*var"(k≠q)gq*(⟨σ12q⟩*⟨a′*σ22k⟩ + ⟨a′⟩*⟨σ22k*σ12q⟩ + ⟨σ22k⟩*⟨a′*σ12q⟩ - 2⟨a′⟩*⟨σ12q⟩*⟨σ22k⟩)" + (0 + 1im)*var"∑(i=1:2)(i≠j,k,q)Ωiq*⟨σ22k⟩*⟨σ21i*σ12q⟩" + (0.0 + 1.0im)*var"(k≠q)gk*(⟨a′⟩*⟨σ12k*σ22q⟩ + ⟨σ22q⟩*⟨a′*σ12k⟩ + ⟨σ12k⟩*⟨a′*σ22q⟩ - 2⟨a′⟩*⟨σ22q⟩*⟨σ12k⟩)" + (0.0 - 1.0im)*var"(k≠q)gk*(⟨a⟩*⟨σ21k*σ22q⟩ + ⟨σ22q⟩*⟨a*σ21k⟩ + ⟨σ21k⟩*⟨a*σ22q⟩ - 2⟨a⟩*⟨σ22q⟩*⟨σ21k⟩)" + (0.0 - 1.0im)*var"(k≠q)gq*(⟨σ21q⟩*⟨a*σ22k⟩ + ⟨a⟩*⟨σ22k*σ21q⟩ + ⟨σ22k⟩*⟨a*σ21q⟩ - 2⟨a⟩*⟨σ21q⟩*⟨σ22k⟩)" + (0 + 1im)*var"∑(i=1:2)(i≠j,k,q)Ωiq*⟨σ12q⟩*⟨σ21i*σ22k⟩" + (0 + 1im)*var"∑(i=1:2)(i≠j,k,q)Ωiq*⟨σ21i⟩*⟨σ22k*σ12q⟩" + (0 - 1im)*var"∑(j=1:2)(j≠k,q)Ωkj*⟨σ12j⟩*⟨σ21k*σ22q⟩" + (0 - 1im)*var"∑(j=1:2)(j≠k,q)Ωkj*⟨σ21k⟩*⟨σ12j*σ22q⟩" + (0 - 2im)*var"∑(i=1:2)(i≠j,k,q)Ωiq*⟨σ12q⟩*⟨σ21i⟩*⟨σ22k⟩" + (0 - 1im)*var"∑(j=1:2)(j≠k,q)Ωkj*⟨σ22q⟩*⟨σ12j*σ21k⟩" + (0 + 2im)*var"∑(j=1:2)(j≠q,k)Ωqj*⟨σ12j⟩*⟨σ21q⟩*⟨σ22k⟩" + (0 - 1im)*var"∑(j=1:2)(j≠q,k)Ωqj*⟨σ12j⟩*⟨σ22k*σ21q⟩" + (0 + 2im)*var"∑(j=1:2)(j≠k,q)Ωkj*⟨σ22q⟩*⟨σ12j⟩*⟨σ21k⟩" + (0 - 1im)*var"∑(j=1:2)(j≠q,k)Ωqj*⟨σ21q⟩*⟨σ12j*σ22k⟩" + (0 - 1im)*var"∑(j=1:2)(j≠q,k)Ωqj*⟨σ22k⟩*⟨σ12j*σ21q⟩" - var"(k≠q)Γkk*⟨σ22k*σ22q⟩" - var"(k≠q)Γqq*⟨σ22k*σ22q⟩" - 0.5var"∑(i=1:2)(i≠j,k,q)Γiq*⟨σ12q⟩*⟨σ21i*σ22k⟩" - 0.5var"∑(i=1:2)(i≠j,k,q)Γiq*⟨σ21i⟩*⟨σ22k*σ12q⟩" - 0.5var"∑(i=1:2)(i≠j,k,q)Γiq*⟨σ22k⟩*⟨σ21i*σ12q⟩" - 0.5var"∑(j=1:2)(j≠k,q)Γkj*⟨σ12j⟩*⟨σ21k*σ22q⟩" - 0.5var"∑(j=1:2)(j≠k,q)Γkj*⟨σ21k⟩*⟨σ12j*σ22q⟩" - 0.5var"∑(j=1:2)(j≠k,q)Γkj*⟨σ22q⟩*⟨σ12j*σ21k⟩" - 0.5var"∑(j=1:2)(j≠k,q)Γqj*⟨σ12j⟩*⟨σ22k*σ21q⟩" - 0.5var"∑(j=1:2)(j≠k,q)Γqj*⟨σ21q⟩*⟨σ12j*σ22k⟩" - 0.5var"∑(j=1:2)(j≠k,q)Γqj*⟨σ22k⟩*⟨σ12j*σ21q⟩"
# ∂ₜ(⟨σ21k*σ22q⟩) = var"∑(i=1:2)(i≠j,k,q)Γiq*⟨σ12q⟩*⟨σ21i⟩*⟨σ21k⟩" + var"∑(j=1:2)(j≠k,q)Γqj*⟨σ12j⟩*⟨σ21k⟩*⟨σ21q⟩" + (0.0 + 1.0im)*var"(k≠q)gk*⟨a′*σ22q⟩" + (0.0 - 2.0im)*var"(k≠q)gk*(⟨a′⟩*⟨σ22k*σ22q⟩ + ⟨σ22k⟩*⟨a′*σ22q⟩ + ⟨σ22q⟩*⟨a′*σ22k⟩ - 2⟨a′⟩*⟨σ22q⟩*⟨σ22k⟩)" + (0.0 - 1.0im)*var"(k≠q)gq*(⟨a⟩*⟨σ21k*σ21q⟩ + ⟨σ21q⟩*⟨a*σ21k⟩ + ⟨σ21k⟩*⟨a*σ21q⟩ - 2⟨a⟩*⟨σ21k⟩*⟨σ21q⟩)" + (0.0 + 1.0im)*var"(k≠q)gq*(⟨σ21k⟩*⟨a′*σ12q⟩ + ⟨σ12q⟩*⟨a′*σ21k⟩ + ⟨a′⟩*⟨σ21k*σ12q⟩ - 2⟨a′⟩*⟨σ12q⟩*⟨σ21k⟩)" + (0 + 1im)*var"∑(i=1:2)(i≠j,k,q)Ωiq*⟨σ12q⟩*⟨σ21i*σ21k⟩" + (0 + 1im)*var"∑(i=1:2)(i≠j,k,q)Ωiq*⟨σ21i⟩*⟨σ21k*σ12q⟩" + (0 - 2im)*var"∑(i=1:2)(i≠j,k,q)Ωiq*⟨σ12q⟩*⟨σ21i⟩*⟨σ21k⟩" + (0 + 1im)*var"∑(i=1:2)(i≠j,k,q)Ωiq*⟨σ21k⟩*⟨σ21i*σ12q⟩" + (0.0 + 1.0im)*var"(k≠q)Δa*⟨σ21k*σ22q⟩" + (0 - 1im)*var"∑(j=1:2)(j≠q,k)Ωqj*⟨σ12j⟩*⟨σ21k*σ21q⟩" + (0 - 1im)*var"∑(j=1:2)(j≠q,k)Ωqj*⟨σ21k⟩*⟨σ12j*σ21q⟩" + (0 - 1im)*var"∑(j=1:2)(j≠q,k)Ωqj*⟨σ21q⟩*⟨σ12j*σ21k⟩" + (0 + 2im)*var"∑(j=1:2)(j≠q,k)Ωqj*⟨σ12j⟩*⟨σ21k⟩*⟨σ21q⟩" - 0.5var"(k≠q)Γkk*⟨σ21k*σ22q⟩" - 0.5var"∑(j=1:2)(j≠k,q)Γqj*⟨σ21q⟩*⟨σ12j*σ21k⟩" - 0.5var"(k≠q)Γqk*⟨σ22k*σ21q⟩" - 0.5var"∑(i=1:2)(i≠j,k,q)Γiq*⟨σ12q⟩*⟨σ21i*σ21k⟩" - 0.5var"∑(i=1:2)(i≠j,k,q)Γiq*⟨σ21i⟩*⟨σ21k*σ12q⟩" - var"(k≠q)Γqq*⟨σ21k*σ22q⟩" - 0.5var"∑(i=1:2)(i≠j,k,q)Γiq*⟨σ21k⟩*⟨σ21i*σ12q⟩" - 0.5var"∑(j=1:2)(j≠k,q)Γqj*⟨σ12j⟩*⟨σ21k*σ21q⟩" - 0.5var"∑(j=1:2)(j≠k,q)Γqj*⟨σ21k⟩*⟨σ12j*σ21q⟩"
# ∂ₜ(⟨σ12k*σ12q⟩) = var"∑(j=1:2)(j≠k,q)Γkj*⟨σ12j⟩*⟨σ22k*σ12q⟩" + var"∑(j=1:2)(j≠k,q)Γkj*⟨σ12q⟩*⟨σ12j*σ22k⟩" + var"∑(j=1:2)(j≠k,q)Γkj*⟨σ22k⟩*⟨σ12j*σ12q⟩" + var"∑(j=1:2)(j≠k,q)Γqj*⟨σ12j⟩*⟨σ12k*σ22q⟩" + var"∑(j=1:2)(j≠k,q)Γqj*⟨σ12k⟩*⟨σ12j*σ22q⟩" + var"∑(j=1:2)(j≠k,q)Γqj*⟨σ22q⟩*⟨σ12j*σ12k⟩" + (0.0 - 1.0im)*var"(k≠q)gk*⟨a*σ12q⟩" + (0 + 1im)*var"∑(j=1:2)(j≠k,q)Ωqj*⟨σ12j⟩*⟨σ12k*σ22q⟩" + (0.0 + 2.0im)*var"(k≠q)gk*(⟨a⟩*⟨σ22k*σ12q⟩ + ⟨σ22k⟩*⟨a*σ12q⟩ + ⟨σ12q⟩*⟨a*σ22k⟩ - 2⟨a⟩*⟨σ12q⟩*⟨σ22k⟩)" + (0.0 + 2.0im)*var"(k≠q)gq*(⟨σ22q⟩*⟨a*σ12k⟩ + ⟨σ12k⟩*⟨a*σ22q⟩ + ⟨a⟩*⟨σ12k*σ22q⟩ - 2⟨a⟩*⟨σ22q⟩*⟨σ12k⟩)" + (0.0 - 1.0im)*var"(k≠q)gq*⟨a*σ12k⟩" + (0 - 1im)*var"∑(j=1:2)(j≠k,q)Ωkj*⟨σ12j*σ12q⟩" + (0.0 - 2.0im)*var"(k≠q)Δa*⟨σ12k*σ12q⟩" + (0 + 2im)*var"∑(j=1:2)(j≠k,q)Ωkj*⟨σ12j⟩*⟨σ22k*σ12q⟩" + (0 + 2im)*var"∑(j=1:2)(j≠k,q)Ωkj*⟨σ12q⟩*⟨σ12j*σ22k⟩" + (0 - 4im)*var"∑(j=1:2)(j≠k,q)Ωkj*⟨σ12q⟩*⟨σ12j⟩*⟨σ22k⟩" + (0 + 1im)*var"∑(j=1:2)(j≠k,q)Ωqj*⟨σ12k⟩*⟨σ12j*σ22q⟩" + (0 + 1im)*var"∑(j=1:2)(j≠k,q)Ωqj*⟨σ22q⟩*⟨σ12j*σ12k⟩" + (0 - 1im)*var"∑(j=1:2)(j≠q,k)Ωqj*⟨σ12j*σ12k⟩" + (0 + 1im)*var"∑(j=1:2)(j≠q,k)Ωqj*⟨σ12j⟩*⟨σ12k*σ22q⟩" + (0 + 1im)*var"∑(j=1:2)(j≠q,k)Ωqj*⟨σ12k⟩*⟨σ12j*σ22q⟩" + (0 + 1im)*var"∑(j=1:2)(j≠q,k)Ωqj*⟨σ22q⟩*⟨σ12j*σ12k⟩" + (0 + 2im)*var"∑(j=1:2)(j≠k,q)Ωkj*⟨σ22k⟩*⟨σ12j*σ12q⟩" + (0 - 2im)*var"∑(j=1:2)(j≠k,q)Ωqj*⟨σ22q⟩*⟨σ12k⟩*⟨σ12j⟩" + (0 - 2im)*var"∑(j=1:2)(j≠q,k)Ωqj*⟨σ22q⟩*⟨σ12k⟩*⟨σ12j⟩" - 0.5var"(k≠q)Γkk*⟨σ12k*σ12q⟩" - 0.5var"∑(j=1:2)(j≠k)Γqj*⟨σ12j*σ12k⟩" - 0.5var"∑(j=1:2)(j≠k,q)Γkj*⟨σ12j*σ12q⟩" - 2var"∑(j=1:2)(j≠k,q)Γkj*⟨σ12q⟩*⟨σ12j⟩*⟨σ22k⟩" - 2var"∑(j=1:2)(j≠k,q)Γqj*⟨σ22q⟩*⟨σ12k⟩*⟨σ12j⟩"

# %%
eqs_ = evalME(eqs_comp)
1
# Out:
# 1

# %%
eqs_
# Out:
# ∂ₜ(⟨a⟩) = (0 - 1im)*η + (0 - 1im)*Δc*⟨a⟩ + (0 - 1im)*g1*⟨σ121⟩ + (0 - 1im)*g2*⟨σ122⟩ - 0.5κ*⟨a⟩
# ∂ₜ(⟨σ221⟩) = (0 + 1im)*g1*⟨a′*σ121⟩ + (0 - 1im)*g1*⟨a*σ211⟩ + (0 + 1im)*Ω21*⟨σ121*σ212⟩ + (0 - 1im)*Ω12*⟨σ211*σ122⟩ - 0.5Γ21*⟨σ121*σ212⟩ - 0.5Γ12*⟨σ211*σ122⟩ - Γ11*⟨σ221⟩
# ∂ₜ(⟨σ222⟩) = (0 + 1im)*g2*⟨a′*σ122⟩ + (0 - 1im)*g2*⟨a*σ212⟩ + (0 - 1im)*Ω21*⟨σ121*σ212⟩ + (0 + 1im)*Ω12*⟨σ211*σ122⟩ - Γ22*⟨σ222⟩ - 0.5Γ21*⟨σ121*σ212⟩ - 0.5Γ12*⟨σ211*σ122⟩
# ∂ₜ(⟨σ121⟩) = Γ12*⟨σ221*σ122⟩ + (0 - 1im)*g1*⟨a⟩ + (0 + 2im)*g1*⟨a*σ221⟩ + (0 - 1im)*Δa*⟨σ121⟩ + (0 - 1im)*Ω12*⟨σ122⟩ + (0 + 2im)*Ω12*⟨σ221*σ122⟩ - 0.5Γ11*⟨σ121⟩ - 0.5Γ12*⟨σ122⟩
# ∂ₜ(⟨σ122⟩) = Γ21*⟨σ121*σ222⟩ + (0 - 1im)*g2*⟨a⟩ + (0 - 1im)*Ω21*⟨σ121⟩ + (0 + 2im)*g2*⟨a*σ222⟩ + (0 - 1im)*Δa*⟨σ122⟩ + (0 + 2im)*Ω21*⟨σ121*σ222⟩ - 0.5Γ21*⟨σ121⟩ - 0.5Γ22*⟨σ122⟩
# ∂ₜ(⟨a′*σ121⟩) = (0 + 2im)*g1*(⟨σ221⟩*⟨a′*a⟩ + ⟨a⟩*⟨a′*σ221⟩ + ⟨a′⟩*⟨a*σ221⟩ - 2⟨a′⟩*⟨a⟩*⟨σ221⟩) + (0 + 1im)*g1*⟨σ221⟩ + (0 - 1im)*g1*⟨a′*a⟩ + (0 - 1im)*Δa*⟨a′*σ121⟩ + (0 + 1im)*Δc*⟨a′*σ121⟩ + (0 - 1im)*Ω12*⟨a′*σ122⟩ + (0 + 1im)*η*⟨σ121⟩ + Γ12*⟨σ221⟩*⟨a′*σ122⟩ + Γ12*⟨σ122⟩*⟨a′*σ221⟩ + (0 + 1im)*g2*⟨σ121*σ212⟩ + Γ12*⟨a′⟩*⟨σ221*σ122⟩ + (0 + 2im)*Ω12*⟨a′⟩*⟨σ221*σ122⟩ + (0 + 2im)*Ω12*⟨σ122⟩*⟨a′*σ221⟩ + (0 + 2im)*Ω12*⟨σ221⟩*⟨a′*σ122⟩ + (0 - 4im)*Ω12*⟨a′⟩*⟨σ221⟩*⟨σ122⟩ - 0.5Γ11*⟨a′*σ121⟩ - 0.5Γ12*⟨a′*σ122⟩ - 0.5κ*⟨a′*σ121⟩ - 2Γ12*⟨a′⟩*⟨σ221⟩*⟨σ122⟩
# ∂ₜ(⟨a′*σ122⟩) = (0 + 2im)*g2*(⟨a⟩*⟨a′*σ222⟩ + ⟨a′⟩*⟨a*σ222⟩ + ⟨σ222⟩*⟨a′*a⟩ - 2⟨a′⟩*⟨a⟩*⟨σ222⟩) + (0 + 1im)*g1*⟨σ211*σ122⟩ + (0 + 1im)*g2*⟨σ222⟩ + (0 + 1im)*η*⟨σ122⟩ + (0 - 1im)*g2*⟨a′*a⟩ + Γ21*⟨σ121⟩*⟨a′*σ222⟩ + (0 - 1im)*Δa*⟨a′*σ122⟩ + (0 + 1im)*Δc*⟨a′*σ122⟩ + (0 - 1im)*Ω21*⟨a′*σ121⟩ + Γ21*⟨a′⟩*⟨σ121*σ222⟩ + Γ21*⟨σ222⟩*⟨a′*σ121⟩ + (0 + 2im)*Ω21*⟨σ121⟩*⟨a′*σ222⟩ + (0 + 2im)*Ω21*⟨σ222⟩*⟨a′*σ121⟩ + (0 + 2im)*Ω21*⟨a′⟩*⟨σ121*σ222⟩ + (0 - 4im)*Ω21*⟨a′⟩*⟨σ222⟩*⟨σ121⟩ - 0.5Γ21*⟨a′*σ121⟩ - 0.5Γ22*⟨a′*σ122⟩ - 0.5κ*⟨a′*σ122⟩ - 2Γ21*⟨a′⟩*⟨σ222⟩*⟨σ121⟩
# ∂ₜ(⟨a*σ221⟩) = (0 - 1im)*g1*(⟨σ211⟩*⟨a*a⟩ + 2⟨a⟩*⟨a*σ211⟩ - 2(⟨a⟩^2)*⟨σ211⟩) + (0 + 1im)*g1*(⟨a′⟩*⟨a*σ121⟩ + ⟨σ121⟩*⟨a′*a⟩ + ⟨a⟩*⟨a′*σ121⟩ - 2⟨a′⟩*⟨a⟩*⟨σ121⟩) + (0 - 1im)*η*⟨σ221⟩ + (0 - 1im)*Δc*⟨a*σ221⟩ + (0 - 1im)*g2*⟨σ221*σ122⟩ + (0 - 1im)*Ω12*⟨σ211⟩*⟨a*σ122⟩ + (0.0 + 1.0im)*Ω21*⟨a⟩*⟨σ121*σ212⟩ + Γ21*⟨a⟩*⟨σ121⟩*⟨σ212⟩ + (-0.5 + 0.0im)Γ21*⟨σ121⟩*⟨a*σ212⟩ + (-0.5 + 0.0im)Γ21*⟨a⟩*⟨σ121*σ212⟩ + (0.0 + 1.0im)*Ω21*⟨σ121⟩*⟨a*σ212⟩ + (-0.5 + 0.0im)Γ21*⟨σ212⟩*⟨a*σ121⟩ + (0 - 1im)*Ω12*⟨σ122⟩*⟨a*σ211⟩ + (0 - 1im)*Ω12*⟨a⟩*⟨σ211*σ122⟩ + (0.0 + 1.0im)*Ω21*⟨σ212⟩*⟨a*σ121⟩ + Γ12*⟨a⟩*⟨σ211⟩*⟨σ122⟩ + (0.0 - 2.0im)*Ω21*⟨a⟩*⟨σ121⟩*⟨σ212⟩ + (0 + 2im)*Ω12*⟨a⟩*⟨σ211⟩*⟨σ122⟩ - Γ11*⟨a*σ221⟩ - 0.5κ*⟨a*σ221⟩ - 0.5Γ12*⟨σ122⟩*⟨a*σ211⟩ - 0.5Γ12*⟨a⟩*⟨σ211*σ122⟩ - 0.5Γ12*⟨σ211⟩*⟨a*σ122⟩
# ∂ₜ(⟨a*σ222⟩) = (0 - 1im)*g1*⟨σ121*σ222⟩ + (0 - 1im)*Δc*⟨a*σ222⟩ + (0 - 1im)*η*⟨σ222⟩ + (0 - 1im)*g2*(⟨σ212⟩*⟨a*a⟩ + 2⟨a⟩*⟨a*σ212⟩ - 2(⟨a⟩^2)*⟨σ212⟩) + (0 + 1im)*g2*(⟨σ122⟩*⟨a′*a⟩ + ⟨a⟩*⟨a′*σ122⟩ + ⟨a′⟩*⟨a*σ122⟩ - 2⟨a′⟩*⟨a⟩*⟨σ122⟩) + (-0.5 + 0.0im)Γ12*⟨σ122⟩*⟨a*σ211⟩ + Γ21*⟨a⟩*⟨σ121⟩*⟨σ212⟩ + (0.0 + 1.0im)*Ω12*⟨σ211⟩*⟨a*σ122⟩ + (0 - 1im)*Ω21*⟨a⟩*⟨σ121*σ212⟩ + (-0.5 + 0.0im)Γ12*⟨a⟩*⟨σ211*σ122⟩ + (0 - 1im)*Ω21*⟨σ121⟩*⟨a*σ212⟩ + (0.0 + 1.0im)*Ω12*⟨a⟩*⟨σ211*σ122⟩ + (0.0 + 1.0im)*Ω12*⟨σ122⟩*⟨a*σ211⟩ + (0 - 1im)*Ω21*⟨σ212⟩*⟨a*σ121⟩ + Γ12*⟨a⟩*⟨σ211⟩*⟨σ122⟩ + (-0.5 + 0.0im)Γ12*⟨σ211⟩*⟨a*σ122⟩ + (0 + 2im)*Ω21*⟨a⟩*⟨σ121⟩*⟨σ212⟩ + (0.0 - 2.0im)*Ω12*⟨a⟩*⟨σ211⟩*⟨σ122⟩ - 0.5κ*⟨a*σ222⟩ - Γ22*⟨a*σ222⟩ - 0.5Γ21*⟨σ121⟩*⟨a*σ212⟩ - 0.5Γ21*⟨a⟩*⟨σ121*σ212⟩ - 0.5Γ21*⟨σ212⟩*⟨a*σ121⟩
# ∂ₜ(⟨σ121*σ212⟩) = (0.0 - 1.0im)*g1*⟨a*σ212⟩ + (0.0 - 2.0im)*g2*(⟨σ222⟩*⟨a′*σ121⟩ + ⟨σ121⟩*⟨a′*σ222⟩ + ⟨a′⟩*⟨σ121*σ222⟩ - 2⟨a′⟩*⟨σ222⟩*⟨σ121⟩) + (0.0 + 1.0im)*g2*⟨a′*σ121⟩ + (0.0 - 1.0im)*Ω12*⟨σ222⟩ + (0.0 + 2.0im)*g1*(⟨σ212⟩*⟨a*σ221⟩ + ⟨a⟩*⟨σ221*σ212⟩ + ⟨σ221⟩*⟨a*σ212⟩ - 2⟨a⟩*⟨σ212⟩*⟨σ221⟩) + 2.0Γ12*⟨σ221*σ222⟩ + (0.0 + 1.0im)*Ω12*⟨σ221*σ222⟩ - 0.5Γ12*⟨σ222⟩ - 0.5Γ12*⟨σ221⟩ - 0.5Γ11*⟨σ121*σ212⟩ - 0.5Γ22*⟨σ121*σ212⟩
# ∂ₜ(⟨σ221*σ122⟩) = (0.0 + 1.0im)*g1*(⟨a′⟩*⟨σ121*σ122⟩ + ⟨σ122⟩*⟨a′*σ121⟩ + ⟨σ121⟩*⟨a′*σ122⟩ - 2⟨a′⟩*⟨σ121⟩*⟨σ122⟩) + (0.0 - 1.0im)*g1*(⟨σ122⟩*⟨a*σ211⟩ + ⟨a⟩*⟨σ211*σ122⟩ + ⟨σ211⟩*⟨a*σ122⟩ - 2⟨a⟩*⟨σ211⟩*⟨σ122⟩) + (0.0 - 1.0im)*g2*⟨a*σ221⟩ + (0.0 + 1.0im)*Ω21*⟨σ121*σ222⟩ + (0.0 - 1.0im)*Δa*⟨σ221*σ122⟩ + (0.0 + 2.0im)*g2*(⟨σ221⟩*⟨a*σ222⟩ + ⟨σ222⟩*⟨a*σ221⟩ + ⟨a⟩*⟨σ221*σ222⟩ - 2⟨a⟩*⟨σ222⟩*⟨σ221⟩) - Γ11*⟨σ221*σ122⟩ - 0.5Γ21*⟨σ121*σ222⟩ - 0.5Γ22*⟨σ221*σ122⟩
# ∂ₜ(⟨a′*a⟩) = (0 - 1im)*η*⟨a′⟩ + (0 + 1im)*η*⟨a⟩ + (0 - 1im)*g1*⟨a′*σ121⟩ + (0 - 1im)*g2*⟨a′*σ122⟩ + (0 + 1im)*g1*⟨a*σ211⟩ + (0 + 1im)*g2*⟨a*σ212⟩ - κ*⟨a′*a⟩
# ∂ₜ(⟨a*a⟩) = (0 - 2im)*η*⟨a⟩ + (0 - 2im)*Δc*⟨a*a⟩ + (0 - 2im)*g1*⟨a*σ121⟩ + (0 - 2im)*g2*⟨a*σ122⟩ - κ*⟨a*a⟩
# ∂ₜ(⟨a*σ121⟩) = (0 + 2im)*g1*(⟨σ221⟩*⟨a*a⟩ + 2⟨a⟩*⟨a*σ221⟩ - 2(⟨a⟩^2)*⟨σ221⟩) + (0 - 1im)*η*⟨σ121⟩ + (0 - 1im)*g1*⟨a*a⟩ + (0 - 1im)*g2*⟨σ121*σ122⟩ + (0 - 1im)*Δa*⟨a*σ121⟩ + (0 - 1im)*Δc*⟨a*σ121⟩ + (0 - 1im)*Ω12*⟨a*σ122⟩ + Γ12*⟨a⟩*⟨σ221*σ122⟩ + Γ12*⟨σ122⟩*⟨a*σ221⟩ + Γ12*⟨σ221⟩*⟨a*σ122⟩ + (0 + 2im)*Ω12*⟨σ221⟩*⟨a*σ122⟩ + (0 + 2im)*Ω12*⟨σ122⟩*⟨a*σ221⟩ + (0 + 2im)*Ω12*⟨a⟩*⟨σ221*σ122⟩ + (0 - 4im)*Ω12*⟨a⟩*⟨σ221⟩*⟨σ122⟩ - 0.5Γ11*⟨a*σ121⟩ - 0.5Γ12*⟨a*σ122⟩ - 0.5κ*⟨a*σ121⟩ - 2Γ12*⟨a⟩*⟨σ221⟩*⟨σ122⟩
# ∂ₜ(⟨a*σ122⟩) = (0 - 1im)*η*⟨σ122⟩ + (0 - 1im)*g2*⟨a*a⟩ + (0 - 1im)*Ω21*⟨a*σ121⟩ + (0 + 2im)*g2*(⟨σ222⟩*⟨a*a⟩ + 2⟨a⟩*⟨a*σ222⟩ - 2(⟨a⟩^2)*⟨σ222⟩) + Γ21*⟨σ121⟩*⟨a*σ222⟩ + (0 - 1im)*Δa*⟨a*σ122⟩ + (0 - 1im)*Δc*⟨a*σ122⟩ + Γ21*⟨a⟩*⟨σ121*σ222⟩ + Γ21*⟨σ222⟩*⟨a*σ121⟩ + (0 - 1im)*g1*⟨σ121*σ122⟩ + (0 + 2im)*Ω21*⟨σ121⟩*⟨a*σ222⟩ + (0 + 2im)*Ω21*⟨a⟩*⟨σ121*σ222⟩ + (0 + 2im)*Ω21*⟨σ222⟩*⟨a*σ121⟩ + (0 - 4im)*Ω21*⟨a⟩*⟨σ222⟩*⟨σ121⟩ - 0.5Γ21*⟨a*σ121⟩ - 0.5Γ22*⟨a*σ122⟩ - 0.5κ*⟨a*σ122⟩ - 2Γ21*⟨a⟩*⟨σ222⟩*⟨σ121⟩
# ∂ₜ(⟨σ221*σ222⟩) = (0.0 - 1.0im)*g1*(⟨a⟩*⟨σ211*σ222⟩ + ⟨σ222⟩*⟨a*σ211⟩ + ⟨σ211⟩*⟨a*σ222⟩ - 2⟨a⟩*⟨σ222⟩*⟨σ211⟩) + (0.0 + 1.0im)*g1*(⟨σ222⟩*⟨a′*σ121⟩ + ⟨σ121⟩*⟨a′*σ222⟩ + ⟨a′⟩*⟨σ121*σ222⟩ - 2⟨a′⟩*⟨σ222⟩*⟨σ121⟩) + (0.0 + 1.0im)*g2*(⟨σ221⟩*⟨a′*σ122⟩ + ⟨σ122⟩*⟨a′*σ221⟩ + ⟨a′⟩*⟨σ221*σ122⟩ - 2⟨a′⟩*⟨σ221⟩*⟨σ122⟩) + (0.0 - 1.0im)*g2*(⟨σ212⟩*⟨a*σ221⟩ + ⟨a⟩*⟨σ221*σ212⟩ + ⟨σ221⟩*⟨a*σ212⟩ - 2⟨a⟩*⟨σ212⟩*⟨σ221⟩) - Γ11*⟨σ221*σ222⟩ - Γ22*⟨σ221*σ222⟩
# ∂ₜ(⟨σ211*σ222⟩) = (0.0 + 1.0im)*g2*(⟨σ211⟩*⟨a′*σ122⟩ + ⟨σ122⟩*⟨a′*σ211⟩ + ⟨a′⟩*⟨σ211*σ122⟩ - 2⟨a′⟩*⟨σ211⟩*⟨σ122⟩) + (0.0 - 2.0im)*g1*(⟨a′⟩*⟨σ221*σ222⟩ + ⟨σ222⟩*⟨a′*σ221⟩ + ⟨σ221⟩*⟨a′*σ222⟩ - 2⟨a′⟩*⟨σ222⟩*⟨σ221⟩) + (0.0 + 1.0im)*g1*⟨a′*σ222⟩ + (0.0 - 1.0im)*g2*(⟨σ212⟩*⟨a*σ211⟩ + ⟨a⟩*⟨σ211*σ212⟩ + ⟨σ211⟩*⟨a*σ212⟩ - 2⟨a⟩*⟨σ211⟩*⟨σ212⟩) + (0.0 + 1.0im)*Δa*⟨σ211*σ222⟩ - 0.5Γ11*⟨σ211*σ222⟩ - 0.5Γ21*⟨σ221*σ212⟩ - Γ22*⟨σ211*σ222⟩
# ∂ₜ(⟨σ121*σ122⟩) = (0.0 + 2.0im)*g1*(⟨σ221⟩*⟨a*σ122⟩ + ⟨σ122⟩*⟨a*σ221⟩ + ⟨a⟩*⟨σ221*σ122⟩ - 2⟨a⟩*⟨σ221⟩*⟨σ122⟩) + (0.0 - 1.0im)*g2*⟨a*σ121⟩ + (0.0 + 2.0im)*g2*(⟨a⟩*⟨σ121*σ222⟩ + ⟨σ222⟩*⟨a*σ121⟩ + ⟨σ121⟩*⟨a*σ222⟩ - 2⟨a⟩*⟨σ222⟩*⟨σ121⟩) + (0.0 - 1.0im)*g1*⟨a*σ122⟩ + (0.0 - 2.0im)*Δa*⟨σ121*σ122⟩ - 0.5Γ11*⟨σ121*σ122⟩ - 0.5Γ22*⟨σ121*σ122⟩

# %%
u0 = zeros(ComplexF64, length(eqs_))
# parameter
Γ_ = 1.0
d = 2π*0.08 #0.08λ
θ = π/2

Ωij_(i,j) = Γ_*(-3/4)*( (1-(cos(θ))^2)*cos(d)/d-(1-3*(cos(θ))^2)*(sin(d)/(d^2)+(cos(d)/(d^3))) )
function Γij_(i,j)
    i==j ? Γ_ : Γ_*(3/2)*( (1-(cos(θ))^2)*sin(d)/d+(1-3*(cos(θ))^2)*((cos(d)/(d^2))-(sin(d)/(d^3))))
end

ΓMatrix = [Γij_(i,j) for i = 1:N, j=1:N]
ΩMatrix = [Ωij_(i,j) for i = 1:N, j=1:N]

g_ = 2Γ_
κ_ = 20Γ_
Δa_ = 0Γ_
Δc_ = 0Γ_
η_ = κ_/100

g_v = [g_*(-1)^j for j=1:j_ind.rangeN] 

#create Value maps for all the possible entries that Γ and Ω can have
valMap1 = createValueMap(g(j_ind),g_v)
valMap2 = createValueMap(Γ_ij,ΓMatrix)
valMap3 = createValueMap(Ω_ij,ΩMatrix)
valMap = collect(merge(valMap1,valMap2,valMap3))

@named sys = ODESystem(eqs_)
# Out:
# Model sys with 18 equations
# States (18):
#   var"⟨a⟩"(t)
#   var"⟨σ221⟩"(t)
#   var"⟨σ222⟩"(t)
#   var"⟨σ121⟩"(t)
#   var"⟨σ122⟩"(t)
#   var"⟨a′*σ121⟩"(t)
# ⋮
# Parameters (12):
#   Δc
#   η
#   g1
#   κ
#   g2
#   Ω21
# ⋮

# %%
ps = [Δc, η, Δa, κ]
p0 = [Δc_, η_, Δa_, κ_]

Δ_ls = [-10:0.05:10;]Γ_
n_ls = zeros(length(Δ_ls))

for i=1:length(Δ_ls)
    Δc_i = Δ_ls[i]
    Δa_i = Δc_i + Ωij_(1,2) #cavity on resonace with the shifted collective emitter
    p0_i = [Δc_i, η_, Δa_i, κ_]
    ps_ = vcat(ps.=>p0_i,valMap) #Combine all the parameters + values to one list for solving
    prob = ODEProblem(sys,u0,(0.0, 20Γ_), ps_);
    #prob = ODEProblem(sys,u0,(0.0, 20Γ_), ps.=>p0_i);
    prob_ss = SteadyStateProblem(prob);
    sol_ss = solve(prob_ss, DynamicSS(Tsit5(); abstol=1e-8, reltol=1e-8),
        reltol=1e-14, abstol=1e-14, maxiters=5e7)
    n_ls[i] = abs2(sol_ss[a])
end

# %%
T = n_ls ./ maximum(n_ls)
plot(Δ_ls, T, xlabel="Δ/Γ", ylabel="T", legend=false)
